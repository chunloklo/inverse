# %%
import tensorflow as tf

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
import numpy as np

# %%
ship_index = np.where(y_train == 8)

# %%
ship_index
# Out:
# (array([    8,    62,    69, ..., 49968, 49976, 49985], dtype=int64),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int64))

# %%
y_train[8]
# Out:
# array([8], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(x_train[62])

# %%
x_ship = x_train[ship_index[0]]

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_ship.shape
# Out:
# (5000, 32, 32, 3)

# %%
plt.imshow(x_ship[10])

# %%
import skimage

# %%
import numpy as np
import skimage
from skimage import io, filters
def channel_adjust(channel, values):
    orig_size = channel.shape
    flat_channel = channel.flatten()
    adjusted = np.interp(flat_channel, np.linspace(0, 1, len(values)), values)
    return adjusted.reshape(orig_size)

def gotham(image):
    original_image = skimage.img_as_float(image)
    r = original_image[:, :, 0]
    b = original_image[:, :, 2]
    r_boost_lower = channel_adjust(r, [
        0, 0.05, 0.1, 0.2, 0.3,
        0.5, 0.7, 0.8, 0.9,
        0.95, 1.0])
    b_more = np.clip(b + 0.03, 0, 1.0)
    merged = np.stack([r_boost_lower, original_image[:, :, 1], b_more], axis=2)
    blurred = filters.gaussian(merged, sigma=10, multichannel=True)
    final = np.clip(merged * 1.3 - blurred * 0.3, 0, 1.0)
    b = final[:, :, 2]
    b_adjusted = channel_adjust(b, [
        0, 0.047, 0.118, 0.251, 0.318,
        0.392, 0.42, 0.439, 0.475,
        0.561, 0.58, 0.627, 0.671,
        0.733, 0.847, 0.925, 1])
    final[:, :, 2] = b_adjusted
    return final



def split_image_into_channels(image):
    """Look at each image separately"""
    red_channel = image[:, :, 0]
    green_channel = image[:, :, 1]
    blue_channel = image[:, :, 2]
    return red_channel, green_channel, blue_channel


def merge_channels(red, green, blue):
    """Merge channels back into an image"""
    return np.stack([red, green, blue], axis=2)


def sharpen(image, a, b):
    """Sharpening an image: Blur and then subtract from original"""
    blurred = skimage.filters.gaussian_filter(image, sigma=10, multichannel=True)
    sharper = np.clip(image * a - blurred * b, 0, 1.0)
    return sharper


def channel_adjust(channel, values):
    # preserve the original size, so we can reconstruct at the end
    orig_size = channel.shape
    # flatten the image into a single array
    flat_channel = channel.flatten()

    # this magical numpy function takes the values in flat_channel
    # and maps it from its range in [0, 1] to its new squeezed and
    # stretched range
    adjusted = np.interp(flat_channel, np.linspace(0, 1, len(values)), values)

    # put back into the original image shape
    return adjusted.reshape(orig_size)

def contrast_adjust(image, values):
    r, g, b = split_image_into_channels(image)
    r = channel_adjust(r, values)
    g = channel_adjust(g, values)
    b = channel_adjust(b, values)
    adjusted_im = merge_channels(r, g, b)
    return adjusted_im
    
from skimage import color
def change_saturation(image, offset):
    hsv = color.rgb2hsv(image)
    hsv[:, :, 1] = np.clip(hsv[:, :, 1] * offset, 0, 1)
    return color.hsv2rgb(hsv)

def test_filter(image):
    original_image = skimage.img_as_float(image)
    r, g, b = split_image_into_channels(original_image)
    r_interp = channel_adjust(r, [0, 0.8, 1.0])
    red_channel_adj = merge_channels(r_interp, g, b)
    return red_channel_adj

# %%
import matplotlib.pyplot as plt
someIm = plt.imread('4.jpg')
plt.imshow(someIm)

# %%
#Claredon
im = someIm
#im = change_saturation(im, 1.5)
#im = contrast_adjust(im, [0, 0.1, 0.5, 0.7, 0.9, 1])
im = skimage.img_as_float(im)
r, g, b = split_image_into_channels(im)
r = channel_adjust(r, [0, 0.20, 0.5, 0.9, 1])
g = channel_adjust(g, [0, 0.25, 0.6, 0.8, 1])
b = channel_adjust(b, [0, 0.3, 0.55, 0.8, 1])
im = merge_channels(r, g, b)
plt.imshow(im)

# %%
#Gingham filter
im = someIm
#im = change_saturation(im, 1.5)
#im = contrast_adjust(im, [0, 0.1, 0.5, 0.7, 0.9, 1])
im = skimage.img_as_float(im)
r, g, b = split_image_into_channels(im)
r = channel_adjust(r, [0.2, 0.4, 0.7, 0.85, 1])
g = channel_adjust(g, [0.2, 0.35, 0.6, 0.8, .9])
b = channel_adjust(b, [0.2, 0.35, 0.6, 0.8, .9])
im = merge_channels(r, g, b)
plt.imshow(im)

# %%
#Juno filter
im = someIm
im = skimage.img_as_float(im)
#im = change_saturation(im, 1.5)
im = contrast_adjust(im, [0, 0.15, 0.5, 0.85, 1])
r, g, b = split_image_into_channels(im)
#r = channel_adjust(r, [0.2, 0.4, 0.7, 0.85, 1])
g = channel_adjust(g, [0.1, 0.5, 1])
#b = channel_adjust(b, [0.2, 0.35, 0.6, 0.8, .9])
im = merge_channels(r, g, b)
plt.imshow(im)

# %%
#Lark filter
im = someIm
im = skimage.img_as_float(im)
#im = change_saturation(im, 1.5)
im = contrast_adjust(im, [0, 0.2, 0.5, 0.85, 1])
r, g, b = split_image_into_channels(im)
#r = channel_adjust(r, [0.2, 0.4, 0.7, 0.85, 1])
g = channel_adjust(g, [0.1, 0.28, 0.55, 0.8, 1])
#b = channel_adjust(b, [0.2, 0.35, 0.6, 0.8, .9])
im = merge_channels(r, g, b)
plt.imshow(im)

# %%
#Reyes filter
im = someIm
im = skimage.img_as_float(im)
#im = change_saturation(im, 1.5)
im = contrast_adjust(im, [0.1, 0.5, 0.8, 0.9, 1])
r, g, b = split_image_into_channels(im)
r = channel_adjust(r, [0.0, 0.25, 0.55, 0.76, 1])
g = channel_adjust(g, [0.0, 0.25, 0.50, 0.75, 0.97])
b = channel_adjust(b, [0.0, 0.22, 0.5, 0.75, .9])
im = merge_channels(r, g, b)
plt.imshow(im)

# %%
plt.imshow(someIm)

# %%
from instaFilters import *
import matplotlib.pyplot as plt
plt.imshow(reyes(someIm))

# %%
plt.imshow((x_ship[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5f28db0728f4> in <module>
# ----> 1 plt.imshow((x_ship[1]))
#
# NameError: name 'x_ship' is not defined

# %%
im = x_ship[1]
im = change_saturation(im, 1.5)
im = contrast_adjust(im, [0, 0.1, 0.5, 0.7, 0.9, 1])
r, g, b = split_image_into_channels(im)
r = channel_adjust(r, [0, 0.2, 0.5, 0.9, 1])
g = channel_adjust(g, [0, 0.25, 0.6, 0.8, 1])
b = channel_adjust(b, [0, 0.3, 0.55, 0.7, 1])
im = merge_channels(r, g, b)
plt.imshow(im)

# %%
x_gotham = np.array([gotham(image) for image in x_ship[:5000]])

# %%
plt.imshow(x_gotham[40])

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
y_ship = np.array([0] * 5000).reshape(5000, 1)

# %%
y_ship
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
y_gotham = np.array([1] * 5000).reshape(5000, 1)

# %%
y_gotham
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
x_ship.shape
# Out:
# (5000, 32, 32, 3)

# %%
np.vstack((x_ship, x_gotham)).shape
# Out:
# (10000, 32, 32, 3)

# %%
ship_filter_data = np.vstack((x_ship, x_gotham))
ship_filter_label = np.vstack((y_ship, y_gotham))

# %%
ship_filter_label.shape
# Out:
# (10000, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ship_filter_data, ship_filter_label, test_size=0.33, random_state=42)

# %%
X_flat = X_train.reshape(6700, 32 * 32* 3)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)
clf.fit(X_flat, y_train)
# Out:
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
X_test.shape
# Out:
# (3300, 32, 32, 3)

# %%
X_test_flat = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2]* X_test.shape[3])

# %%
clf.score(X_test_flat, y_test)
# Out:
# 1.0

# %%
plt.imshow(x_ship[0])
clf.predict([x_ship[0].flatten()])
# Out:
# array([0])

# %%
plt.imshow(x_gotham[0])
clf.predict([x_gotham[0].flatten()])
# Out:
# array([1])

# %%
scores = cross_val_score(clf, X_flat, y_train, cv=5)
# Out:
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Chunlok Lo\AppData\Local\conda\conda\envs\magiclearning\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)

# %%
plt.imshow(x_test[0])
clf.predict([x_ship[2].flatten()])
# Out:
# array([0])

# %%
plt.imshow(x_gotham[2])
clf.predict([x_gotham[2].flatten()])
# Out:
# array([1])

# %%
novel_im = plt.imread("./ship.jpg")

# %%
novel_im.shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(novel_im)
clf.predict([novel_im.flatten()])
# Out:
# array([0])

# %%
plt.imshow(gotham(novel_im))
clf.predict([gotham(novel_im).flatten()])
# Out:
# array([1])
